# %% [markdown]
# Задача 1: Найдите всех женщин с IP-адресом, начинающимся на "1" и вывести их полные имена
#
# Задача 2:  Создайте новый столбец domain, который будет содержать домен из электронной почты (например, для zsheara0@buzzfeed.com домен — buzzfeed.com).
#
# Задача 3: Найдите все уникальные домены из столбца domain.

# %%
import pandas as pd

df = pd.read_csv('hw_DE_12.csv')
df
# Out:
#        id first_name  last_name                        email   gender  \
# 0       1    Zebulon     Sheara        zsheara0@buzzfeed.com     Male
# 1       2      Gabby      Hundy           ghundy1@dyndns.org     Male
# 2       3     Zaneta    Macewan         zmacewan2@dyndns.org   Female
# 3       4       Linn     Steely             lsteely3@psu.edu     Male
# 4       5     Althea      Segar            asegar4@prlog.org   Female
# ..    ...        ...        ...                          ...      ...
# 995   996    Zsa zsa  McGarahan  zmcgarahanrn@craigslist.org   Female
# 996   997         Al   Villiers  avilliersro@nydailynews.com  Agender
# 997   998   Natalina  Clavering        nclaveringrp@jugem.jp   Female
# 998   999     Gretta  Witheford   gwithefordrq@discovery.com   Female
# 999  1000      Tadio   Feighney        tfeighneyrr@google.es     Male
#
#          ip_address
# 0    26.254.115.173
# 1    86.222.142.186
# 2      20.98.185.65
# 3    65.253.237.106
# ...

# %% [markdown]
# Найдите всех женщин с IP-адресом, начинающимся на "1" и вывести их полные имена

# %%
df['full_name'] = df['first_name'] + ' ' + df['last_name']
# df.query("ip_address.str.startswith('1')")['full_name']
df.loc[df['ip_address'].str.startswith('1'), ['full_name', 'ip_address']]
# Out:
#                full_name       ip_address
# 8       Kaile Clementson    147.21.239.61
# 10        Melosa Boneham   176.120.71.216
# 11        Deina Frisdick    146.176.89.94
# 15      Mamie Wainwright  163.100.199.174
# 16   Humfried Ohanessian    16.207.33.214
# ..                   ...              ...
# 990         Boone Gerrey    191.139.46.86
# 993    Morganica Pierton   150.213.150.57
# 996          Al Villiers      168.3.4.142
# 997   Natalina Clavering    16.223.145.44
# 999       Tadio Feighney    154.243.103.8
#
# [431 rows x 2 columns]

# %% [markdown]
# Задача 3: Найдите все уникальные домены из столбца domain.
# УКАЗАНЫ 2 способа решения!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
# a = df['email']

# list_domain= []

# for domain in a:
#     domain = domain.split('@')[1]

#     list_domain.append(domain)
    

# list_domain

# df['domain'] = list_domain


# ИЛИ ДРУГОЙ ВАРИАНТ:

df['domain'] = df['email'].str.split(pat='@').str[1]

df
# Out:
#        id first_name  last_name                        email   gender  \
# 0       1    Zebulon     Sheara        zsheara0@buzzfeed.com     Male
# 1       2      Gabby      Hundy           ghundy1@dyndns.org     Male
# 2       3     Zaneta    Macewan         zmacewan2@dyndns.org   Female
# 3       4       Linn     Steely             lsteely3@psu.edu     Male
# 4       5     Althea      Segar            asegar4@prlog.org   Female
# ..    ...        ...        ...                          ...      ...
# 995   996    Zsa zsa  McGarahan  zmcgarahanrn@craigslist.org   Female
# 996   997         Al   Villiers  avilliersro@nydailynews.com  Agender
# 997   998   Natalina  Clavering        nclaveringrp@jugem.jp   Female
# 998   999     Gretta  Witheford   gwithefordrq@discovery.com   Female
# 999  1000      Tadio   Feighney        tfeighneyrr@google.es     Male
#
#          ip_address           full_name           domain
# 0    26.254.115.173      Zebulon Sheara     buzzfeed.com
# ...

# %% [markdown]
# Задача 3: Найдите все уникальные домены из столбца domain.
# УКАЗАНЫ 2 способа решения!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
# df['domain'].unique()
#здесь возвращается список уникальных значений, без изменения исходного df

# 2 Вариант

unique_names_df = df['domain'].drop_duplicates()
unique_names_df
# Out:
# 0                buzzfeed.com
# 1                  dyndns.org
# 3                     psu.edu
# 4                   prlog.org
# 5                 mozilla.org
#                 ...
# 944               tinypic.com
# 955                taobao.com
# 984    nationalgeographic.com
# 988    scientificamerican.com
# 999                 google.es
# Name: domain, Length: 435, dtype: object
